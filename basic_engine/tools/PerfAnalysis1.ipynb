# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# TEST AUTORELOAD WORKS
# from analysis_utils import mic_check
# mic_check()
# change the code in that function
# mic_check()   #verify output has changed

# %%
from analysis_utils import load_data, build_data

# %%
import numpy as np
import scipy
import sklearn
print str(np.__version__), str(scipy.__version__), str(sklearn.__version__)
# Out:
# 1.14.5 0.19.0 0.19.1

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load perf_test data

# %%
id_str = "GarryKasparovGames.txt-"
gameIds = [id_str + str(i) for i in range(1,5)]

opt_data = load_data(gameIds, 'analysis2', 'opt_yk')

out = build_data(opt_data)

print str(len(opt_data)), str(len(out))
# Out:
# 4 4

# %%
id_str = "GarryKasparovGames.txt-"
gameIds = [id_str + str(i) for i in range(1,5)]
naive_data = load_data(gameIds, 'analysis2', 'naive_yk')
print len(naive_data)
out2 = build_data(naive_data)
# Out:
# 4

# %%
epsilon = 0.001
for i in range(4):
    y = out2[i][2]
    x = out2[i][3]
    plt.scatter(x=x , y=y)
    plt.ylim(0, max(y) + epsilon)
    plt.show()

# %%
epsilon = 0.0001
for i in range(4):
    y = out[i][2]
    x = out[i][3]
    plt.scatter(x=x , y=y)
    plt.ylim(min(y) - epsilon, max(y) + epsilon)
    plt.show()

# %%
# from sklearn import linear_model
# import pandas as pd
# pd.read_table()
# reg = linear_model.LinearRegression()
